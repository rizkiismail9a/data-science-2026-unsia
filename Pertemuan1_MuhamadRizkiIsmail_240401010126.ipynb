# %%
#==========
# PERTEMUAN 1: Notebook pertama data science
#==========

# SEL 1: Output sederhana
print('Hello, Data Science!')
print('Selamat datang di mata kuliah pengantar data science!')
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah pengantar data science!
# Nama : Muhamad Rizki Ismail
# Angkatan: 2024
# IPK : 4.0
# Aktif : True

# %%
# SEL 2: Variabel dan tipe data dasar
nama = "Muhamad Rizki Ismail" #String
angkatan = 2024 #Integer
ipk = 4.00 #Float
aktif = True #Boolean

print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Muhamad Rizki Ismail
# Angkatan: 2024
# IPK : 4.0
# Aktif : True

# %%
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "Github"]
print("\nTools Data Science yang kita pelajari adalah: ")
for i, tool in enumerate(tools, 1):
  print(f' {i}. {tool}')
# Out:
# Tools Data Science yang kita pelajari adalah:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. Github

# %%
# SEL 4: Fungsi sederhana

def perkenalan(nama, prodi, angkatan):
  # Fungsi untuk menampilkan identitas mahasiswa
  return f"Hai! Saya {nama} dari {prodi}, angakatan tahun {angkatan}"

hasil = perkenalan("Rizki", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Rizki dari Informatika, angakatan tahun 2024
